# %%
import json

# %%
# List all possible categories

categories = set([])

for business in open('yelp_dataset/business.json', 'r'):
    business_obj = json.loads(business)
    
    if business_obj["categories"] == None:
        continue
    
    for c in business_obj["categories"].split(","):
        categories.add(c.strip(' '))

# %%
categories
# Out:
# {'Walking Tours',
#  'Nail Salons',
#  'Ultrasound Imaging Centers',
#  'Drugstores',
#  'Roadside Assistance',
#  'Beaches',
#  'Game Truck Rental',
#  'Meat Shops',
#  'Bookkeepers',
#  'Specialty Schools',
#  'Sports Clubs',
#  'Dance Clubs',
#  'Homeopathic',
#  'Electronics',
#  'Fitness & Instruction',
#  'Screen Printing/T-Shirt Printing',
#  'Metro Stations',
#  'Bookbinding',
#  'Scottish',
#  'Backflow Services',
#  'Caricatures',
#  'College Counseling',
#  'Vinyl Records',
#  'Ethiopian',
#  'Ski Resorts',
#  'Department Stores',
#  'Duty-Free Shops',
#  'Home Theatre Installation',
#  'Data Recovery',
#  'Massage Schools',
#  'Head Shops',
#  'Scooter Rentals',
#  'Pet Groomers',
#  'Squash',
#  'Condominiums',
#  'Outdoor Furniture Stores',
#  'Medical Law',
#  'Live/Raw Food',
#  'Advertising',
#  'Calabrian',
#  'Estheticians',
#  'Soup',
#  'Holiday Decorations',
#  'Synagogues',
#  'Emergency Medicine',
#  'Syrian',
#  'Tanning Beds',
#  'Traditional Clothing',
# ...
