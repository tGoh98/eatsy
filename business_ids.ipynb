# %%
import json
import ast
from collections import defaultdict

# %%
json_file = open("yelp_dataset/business.json", "r")

# %%
business_dict = defaultdict(dict) 
for line in json_file: 
    curline = json.loads(line)
    if curline['attributes'] is not None:
        attributes = {}
        for j in curline['attributes'].keys():
            attributes[j] = ast.literal_eval(curline['attributes'][j])
    else:
        attributes = {}
    if curline['categories'] is not None:
        categories = {'categories': curline['categories'].split(', ')}
    else:
        categories = {'categories': []}
    business_subdict = attributes.copy()
    business_subdict.update(categories)
    business_dict[curline['business_id']] = business_subdict

# %%
business_dict
# Out:
# defaultdict(dict,
#             {'1SWheh84yJXfytovILXOAQ': {'GoodForKids': False,
#               'categories': ['Golf', 'Active Life']},
#              'QXAEGFB4oINsVuTFxEYKFQ': {'RestaurantsReservations': True,
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': True,
#                'brunch': False,
#                'breakfast': False},
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'Caters': True,
#               'NoiseLevel': 'loud',
#               'RestaurantsTableService': True,
#               'RestaurantsTakeOut': True,
#               'RestaurantsPriceRange2': 2,
#               'OutdoorSeating': False,
#               'BikeParking': False,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'HasTV': False,
#               'WiFi': 'no',
#               'GoodForKids': True,
#               'Alcohol': 'full_bar',
#               'RestaurantsAttire': 'casual',
#               'RestaurantsGoodForGroups': True,
#               'RestaurantsDelivery': False,
#               'categories': ['Specialty Food',
#                'Restaurants',
#                'Dim Sum',
#                'Imported Food',
#                'Food',
#                'Chinese',
#                'Ethnic Food',
#                'Seafood']},
#              'gnKjwL_1w79qoiV3IC_xQQ': {'GoodForKids': True,
#               'NoiseLevel': 'average',
#               'RestaurantsDelivery': False,
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': True,
#                'brunch': False,
#                'breakfast': False},
#               'Alcohol': 'beer_and_wine',
#               'Caters': False,
#               'WiFi': 'no',
#               'RestaurantsTakeOut': True,
#               'BusinessAcceptsCreditCards': True,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'touristy': False,
#                'hipster': False,
#                'divey': False,
#                'classy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'RestaurantsTableService': True,
#               'RestaurantsGoodForGroups': True,
#               'OutdoorSeating': False,
#               'HasTV': True,
#               'BikeParking': True,
#               'RestaurantsReservations': True,
#               'RestaurantsPriceRange2': 2,
#               'RestaurantsAttire': 'casual',
#               'categories': ['Sushi Bars', 'Restaurants', 'Japanese']},
#              'xvX2CttrVhyG2z1dFg_0xw': {'categories': ['Insurance',
#                'Financial Services']},
#              'HhyxOkGAM07SRYtlQ4wMFQ': {'BusinessAcceptsBitcoin': False,
#               'ByAppointmentOnly': True,
#               'BusinessAcceptsCreditCards': True,
#               'categories': ['Plumbing',
#                'Shopping',
#                'Local Services',
#                'Home Services',
#                'Kitchen & Bath',
#                'Home & Garden',
#                'Water Heater Installation/Repair']},
#              '68dUKd8_8liJ7in4aWOSEA': {'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsPriceRange2': 2,
#               'categories': ['Shipping Centers',
#                'Couriers & Delivery Services',
#                'Local Services',
#                'Printing Services']},
#              '5JucpCfHZltJh5r1JabjDg': {'RestaurantsPriceRange2': 2,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'ByAppointmentOnly': True,
#               'categories': ['Beauty & Spas', 'Hair Salons']},
#              'gbQN7vr_caG_A1ugSmGhWg': {'RestaurantsPriceRange2': 3,
#               'GoodForKids': True,
#               'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': False,
#               'BikeParking': False,
#               'categories': ['Hair Salons',
#                'Hair Stylists',
#                'Barbers',
#                "Men's Hair Salons",
#                'Cosmetics & Beauty Supply',
#                'Shopping',
#                'Beauty & Spas']},
#              'Y6iyemLX_oylRpnr38vgMA': {'RestaurantsPriceRange2': 2,
#               'ByAppointmentOnly': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BusinessAcceptsCreditCards': True,
#               'BikeParking': False,
#               'categories': ['Nail Salons', 'Beauty & Spas', 'Day Spas']},
#              '4GBVPIYRvzGh4K4TkRQ_rw': {'ByAppointmentOnly': False,
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsPriceRange2': 2,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'AcceptsInsurance': False,
#               'categories': ['Beauty & Spas',
#                'Nail Salons',
#                'Day Spas',
#                'Massage']},
#              'fcXOEZdXYeZqnQ3lGlOXmg': {'BikeParking': False,
#               'ByAppointmentOnly': False,
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsPriceRange2': 1,
#               'categories': ['Local Services',
#                'Professional Services',
#                'Computers',
#                'Shopping',
#                'Home Services',
#                'IT Services & Computer Repair',
#                'Internet Service Providers',
#                'Web Design']},
#              '1Dfx3zM-rW4n-31KeC8sJg': {'RestaurantsTakeOut': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'WiFi': 'no',
#               'RestaurantsDelivery': False,
#               'OutdoorSeating': False,
#               'RestaurantsAttire': 'casual',
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsGoodForGroups': True,
#               'RestaurantsReservations': False,
#               'HasTV': False,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'touristy': False,
#                'hipster': False,
#                'divey': False,
#                'classy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': False},
#               'Alcohol': 'none',
#               'RestaurantsPriceRange2': 1,
#               'GoodForKids': True,
#               'categories': ['Restaurants',
#                'Breakfast & Brunch',
#                'Mexican',
#                'Tacos',
#                'Tex-Mex',
#                'Fast Food']},
#              '5t3KVdMnFgAYmSl1wYLhmA': {'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'Ambience': {'touristy': False,
#                'hipster': False,
#                'romantic': False,
#                'divey': False,
#                'intimate': False,
#                'trendy': False,
#                'upscale': False,
#                'classy': False,
#                'casual': False},
#               'Music': {'dj': False,
#                'background_music': False,
#                'no_music': False,
#                'jukebox': False,
#                'live': False,
#                'video': False,
#                'karaoke': False},
#               'BikeParking': True,
#               'OutdoorSeating': True,
#               'GoodForKids': False,
#               'NoiseLevel': 'average',
#               'RestaurantsGoodForGroups': True,
#               'GoodForDancing': True,
#               'CoatCheck': False,
#               'WiFi': 'free',
#               'RestaurantsPriceRange2': 1,
#               'HappyHour': True,
#               'Alcohol': 'beer_and_wine',
#               'ByAppointmentOnly': False,
#               'HasTV': True,
#               'RestaurantsReservations': True,
#               'BusinessAcceptsCreditCards': True,
#               'BestNights': {'monday': False,
#                'tuesday': False,
#                'friday': False,
#                'wednesday': False,
#                'thursday': True,
#                'sunday': False,
#                'saturday': True},
#               'categories': ['Bars',
#                'Nightlife',
#                'Pubs',
#                'Barbers',
#                'Beauty & Spas',
#                'Irish Pub']},
#              'fweCYi8FmbJXHCqLnwuk8w': {'RestaurantsPriceRange2': 2,
#               'BusinessAcceptsCreditCards': True,
#               'GoodForKids': True,
#               'RestaurantsDelivery': True,
#               'Alcohol': 'none',
#               'OutdoorSeating': False,
#               'RestaurantsGoodForGroups': True,
#               'RestaurantsTakeOut': True,
#               'RestaurantsReservations': False,
#               'BikeParking': True,
#               'RestaurantsAttire': 'casual',
#               'Ambience': None,
#               'BusinessParking': None,
#               'categories': ['Italian',
#                'Restaurants',
#                'Pizza',
#                'Chicken Wings']},
#              '-K4gAv8_vjx8-2BxkVeRkA': {'RestaurantsTakeOut': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsPriceRange2': 1,
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsDelivery': False,
#               'categories': ['Bakeries', 'Food']},
#              'A98xW4qb7vOTguggHFs7Ng': {'ByAppointmentOnly': False,
#               'BikeParking': True,
#               'WheelchairAccessible': False,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'DogsAllowed': False,
#               'categories': ['Fitness & Instruction', 'Active Life', 'Yoga']},
#              'giC3pVVFxCRR89rApqklyw': {'BusinessAcceptsCreditCards': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'GoodForKids': True,
#               'RestaurantsPriceRange2': 2,
#               'ByAppointmentOnly': True,
#               'categories': ['Hair Stylists',
#                'Beauty & Spas',
#                'Hair Salons',
#                "Men's Hair Salons"]},
#              'PZ-LZzSlhSe9utkQYU8pFg': {'OutdoorSeating': False,
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsDelivery': False,
#               'RestaurantsReservations': True,
#               'RestaurantsAttire': 'casual',
#               'Ambience': {'romantic': True,
#                'intimate': False,
#                'touristy': False,
#                'hipster': False,
#                'divey': False,
#                'classy': True,
#                'trendy': False,
#                'upscale': False,
#                'casual': False},
#               'HasTV': False,
#               'BYOBCorkage': 'no',
#               'NoiseLevel': 'quiet',
#               'RestaurantsTakeOut': True,
#               'RestaurantsPriceRange2': 2,
#               'RestaurantsGoodForGroups': True,
#               'WiFi': 'no',
#               'Caters': True,
#               'GoodForKids': True,
#               'Alcohol': 'full_bar',
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'categories': ['Restaurants', 'Italian']},
#              'nh_kQ16QAoXWwqZ05MPfBQ': {'BusinessAcceptsCreditCards': True,
#               'categories': ['Event Planning & Services',
#                'Photographers',
#                'Professional Services']},
#              'zSpQmEBvRe3IhTUlMSA6HQ': {'AcceptsInsurance': True,
#               'ByAppointmentOnly': False,
#               'GoodForKids': False,
#               'WheelchairAccessible': False,
#               'categories': ['Trainers',
#                'Health & Medical',
#                'Active Life',
#                'Physical Therapy',
#                'Gyms',
#                'Fitness & Instruction']},
#              'dFMxzHygTy6F873843dHAA': {'GoodForKids': True,
#               'categories': ['Arcades', 'Arts & Entertainment']},
#              'lxnuq9wJiwLOPJ4uZU2ljg': {'BusinessAcceptsCreditCards': True,
#               'categories': ['Automotive', 'Car Dealers']},
#              'KWywu2tTEPWmR9JnBc0WyQ': {'BikeParking': False,
#               'Ambience': {'romantic': False,
#                'intimate': True,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': False},
#               'RestaurantsPriceRange2': 2,
#               'HasTV': True,
#               'Music': {'dj': True,
#                'background_music': False,
#                'no_music': False,
#                'jukebox': False,
#                'live': False,
#                'video': False,
#                'karaoke': False},
#               'RestaurantsGoodForGroups': True,
#               'OutdoorSeating': True,
#               'RestaurantsReservations': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': True},
#               'GoodForKids': False,
#               'Alcohol': 'full_bar',
#               'NoiseLevel': 'loud',
#               'BusinessAcceptsCreditCards': True,
#               'GoodForDancing': True,
#               'categories': ['Nightlife',
#                'Arts & Entertainment',
#                'Bars',
#                'Strip Clubs',
#                'Adult Entertainment',
#                'Dance Clubs']},
#              '1RHY4K3BD22FK7Cfftn8Mg': {'RestaurantsTakeOut': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'Ambience': {'touristy': False,
#                'hipster': False,
#                'romantic': False,
#                'divey': False,
#                'intimate': False,
#                'trendy': False,
#                'upscale': False,
#                'classy': False,
#                'casual': False},
#               'RestaurantsDelivery': False,
#               'RestaurantsReservations': False,
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsPriceRange2': 1,
#               'RestaurantsGoodForGroups': True,
#               'DriveThru': False,
#               'GoodForKids': True,
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': False,
#                'dinner': False,
#                'brunch': False,
#                'breakfast': False},
#               'HasTV': False,
#               'OutdoorSeating': False,
#               'categories': ['Sandwiches',
#                'Salad',
#                'Restaurants',
#                'Burgers',
#                'Comfort Food']},
#              'BsMdebN4nZySpGTfXr-7yg': {'BusinessAcceptsCreditCards': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsPriceRange2': 2,
#               'BikeParking': True,
#               'categories': ["Women's Clothing",
#                'Shopping',
#                'Accessories',
#                'Fashion',
#                'Shoe Stores']},
#              'tstimHoMcYbkSC4eBA1wEg': {'BikeParking': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BusinessAcceptsCreditCards': True,
#               'GoodForKids': True,
#               'HappyHour': False,
#               'Alcohol': 'beer_and_wine',
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': True,
#                'brunch': False,
#                'breakfast': False},
#               'OutdoorSeating': False,
#               'WiFi': 'no',
#               'RestaurantsAttire': 'casual',
#               'Caters': False,
#               'RestaurantsReservations': False,
#               'RestaurantsTakeOut': True,
#               'RestaurantsDelivery': False,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'RestaurantsGoodForGroups': True,
#               'NoiseLevel': 'average',
#               'HasTV': True,
#               'RestaurantsPriceRange2': 1,
#               'categories': ['Mexican',
#                'Restaurants',
#                'Patisserie/Cake Shop',
#                'Food',
#                'Bars',
#                'Nightlife']},
#              'C9oCPomVP0mtKa8z99E3gg': {'RestaurantsDelivery': False,
#               'RestaurantsPriceRange2': 2,
#               'RestaurantsTakeOut': True,
#               'BikeParking': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'categories': ['Bakeries', 'Food']},
#              'C9keC4mWuXdl2mYFHZXudQ': {'RestaurantsPriceRange2': 3,
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'categories': ['Fashion',
#                'Sporting Goods',
#                "Men's Clothing",
#                'Shopping',
#                'Sports Wear']},
#              'iojTeSaoPuxm4WeCzDUA6w': {'BusinessAcceptsCreditCards': True,
#               'categories': ['Car Rental',
#                'Windshield Installation & Repair',
#                'Auto Detailing',
#                'Hotels & Travel',
#                'Automotive',
#                'Towing',
#                'Body Shops']},
#              'NDuUMJfrWk52RA-H-OtrpA': {'WiFi': 'no',
#               'BikeParking': True,
#               'RestaurantsPriceRange2': 2,
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsTakeOut': True,
#               'Caters': False,
#               'categories': ['Juice Bars & Smoothies',
#                'Food',
#                'Restaurants',
#                'Fast Food',
#                'Vegan']},
#              'LB6ZyCfUzeX9OLdunHhnOQ': {'BusinessAcceptsCreditCards': True,
#               'RestaurantsPriceRange2': 1,
#               'BikeParking': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'categories': ['Shopping',
#                'Home & Garden',
#                'Department Stores',
#                "Men's Clothing",
#                'Fashion',
#                "Women's Clothing",
#                'Discount Store',
#                'Home Decor']},
#              'mNBp4KI2goFJKDB9VLGP9w': {'categories': ['Automotive',
#                'Auto Repair']},
#              'SP_YXIEwkFPPl_9anCYmpQ': {'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsReservations': True,
#               'GoodForKids': False,
#               'RestaurantsAttire': 'casual',
#               'Alcohol': 'full_bar',
#               'OutdoorSeating': False,
#               'RestaurantsPriceRange2': 2,
#               'NoiseLevel': 'average',
#               'RestaurantsDelivery': False,
#               'WiFi': 'free',
#               'RestaurantsTakeOut': False,
#               'HasTV': False,
#               'BikeParking': True,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'RestaurantsGoodForGroups': True,
#               'Caters': True,
#               'categories': ['Restaurants',
#                'Nightlife',
#                'Breakfast & Brunch',
#                'Vegan',
#                'Food',
#                'Tapas Bars',
#                'Bars',
#                'Southern',
#                'Coffee & Tea']},
#              'irft4YkdNsww4DNf_Aftew': {'BusinessAcceptsCreditCards': True,
#               'RestaurantsPriceRange2': 2,
#               'RestaurantsTakeOut': True,
#               'BikeParking': False,
#               'WiFi': 'free',
#               'Caters': False,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'categories': ['Juice Bars & Smoothies',
#                'Food',
#                'Ice Cream & Frozen Yogurt']},
#              'HVPcIcqiJkrpD36xZFGN6g': {'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': False,
#               'categories': ['Home Services',
#                'Real Estate',
#                'Financial Services',
#                'Banks & Credit Unions',
#                'Mortgage Brokers']},
#              'BvYU3jvGd0TJ7IyZdfiN2Q': {'Alcohol': 'full_bar',
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsAttire': 'casual',
#               'RestaurantsTakeOut': True,
#               'RestaurantsReservations': True,
#               'GoodForKids': False,
#               'RestaurantsGoodForGroups': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'OutdoorSeating': False,
#               'RestaurantsDelivery': False,
#               'RestaurantsPriceRange2': 2,
#               'categories': ['Sandwiches',
#                'Italian',
#                'American (Traditional)',
#                'American (New)',
#                'Seafood',
#                'Steakhouses',
#                'Restaurants']},
#              '0_ohldeFwysbglrTLSGM4Q': {'ByAppointmentOnly': False,
#               'RestaurantsPriceRange2': 2,
#               'BusinessAcceptsCreditCards': False,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'categories': ['Beauty & Spas', 'Barbers']},
#              'M9DM1ktbW-TB7nXu3Z4RDw': {'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': False,
#               'categories': ['Home Services',
#                'Real Estate',
#                'Apartments',
#                'Hotels & Travel',
#                'Vacation Rentals']},
#              'n2kOsDur7tCLygSa87glJQ': {'ByAppointmentOnly': True,
#               'categories': ['Medical Centers',
#                'Doctors',
#                'Obstetricians & Gynecologists',
#                'Health & Medical']},
#              'hgPhZoB3zdiRdlT9FETskw': {'BusinessAcceptsCreditCards': True,
#               'categories': ['Auto Glass Services',
#                'Auto Detailing',
#                'Automotive',
#                'Auto Parts & Supplies',
#                'Auto Customization',
#                'Vehicle Wraps']},
#              '-MsRvdPnuw6QuLn5Vxjruw': {'categories': ['Shopping',
#                'Home Services',
#                'Interior Design',
#                'Rugs',
#                'Furniture Stores',
#                'Home & Garden',
#                'Home Decor',
#                'Mattresses']},
#              'FDI2PkyJBWEVFZ0ndHFg2g': {'BusinessAcceptsCreditCards': False,
#               'ByAppointmentOnly': True,
#               'categories': ['Real Estate',
#                'Home Services',
#                'Mortgage Brokers',
#                'Real Estate Services']},
#              'Qwt9lOpplBAZ7JBrgAqI7g': {'categories': ['Home Services',
#                'Real Estate',
#                'Apartments']},
#              'NBn4hgfGtNz91k3VsDZlmw': {'RestaurantsPriceRange2': 1,
#               'BusinessAcceptsCreditCards': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'GoodForKids': True,
#               'categories': ['Local Services',
#                'Food Banks',
#                'Community Service/Non-Profit']},
#              'teknANRU8ZKnwdIHWYyd8Q': {'ByAppointmentOnly': False,
#               'BusinessAcceptsCreditCards': True,
#               'categories': ['Massage Therapy',
#                'Massage',
#                'Health & Medical',
#                'Beauty & Spas']},
#              'e_EMySqP0uwlVZfd8mRaaQ': {'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsGoodForGroups': True,
#               'OutdoorSeating': False,
#               'RestaurantsPriceRange2': 1,
#               'GoodForKids': True,
#               'RestaurantsDelivery': False,
#               'RestaurantsTakeOut': True,
#               'RestaurantsAttire': 'casual',
#               'categories': ['Chinese', 'Dim Sum', 'Restaurants']},
#              '-l45pZ9izx2mo5RzX2PwMw': {'categories': ["Children's Clothing",
#                'Accessories',
#                'Used',
#                'Vintage & Consignment',
#                'Fashion',
#                "Women's Clothing",
#                'Shopping']},
#              'GWO87Y-IqL54_Ijx6hTYAQ': {'BusinessAcceptsCreditCards': True,
#               'BikeParking': True,
#               'RestaurantsPriceRange2': 2,
#               'Caters': True,
#               'RestaurantsTakeOut': False,
#               'WiFi': 'no',
#               'WheelchairAccessible': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'categories': ['Food',
#                'Desserts',
#                'Juice Bars & Smoothies',
#                'Ice Cream & Frozen Yogurt']},
#              'Jff5hTK1ZMLKS06sOSNWdA': {'RestaurantsPriceRange2': 2,
#               'WiFi': 'free',
#               'categories': ['Hotels & Travel',
#                'Hotels',
#                'Event Planning & Services']},
#              '5ws3QWQXUhqTeLd7IZsDww': {'ByAppointmentOnly': True,
#               'categories': ['Health & Medical', 'Endodontists', 'Dentists']},
#              'mlHC2XcU9Bows6cnYEmRgg': {'Alcohol': 'full_bar',
#               'Caters': False,
#               'Smoking': 'no',
#               'WheelchairAccessible': True,
#               'DogsAllowed': False,
#               'CoatCheck': False,
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsTakeOut': True,
#               'WiFi': 'free',
#               'RestaurantsTableService': True,
#               'HasTV': False,
#               'RestaurantsPriceRange2': 3,
#               'Ambience': {'touristy': False,
#                'hipster': False,
#                'romantic': False,
#                'intimate': False,
#                'trendy': False,
#                'upscale': False,
#                'classy': False,
#                'casual': False},
#               'HappyHour': False,
#               'RestaurantsReservations': True,
#               'BikeParking': True,
#               'RestaurantsAttire': 'dressy',
#               'Music': {'dj': False,
#                'background_music': False,
#                'no_music': False,
#                'jukebox': False,
#                'live': False,
#                'video': False,
#                'karaoke': False},
#               'OutdoorSeating': True,
#               'BestNights': {'monday': False,
#                'tuesday': False,
#                'friday': False,
#                'wednesday': False,
#                'thursday': False,
#                'sunday': True,
#                'saturday': False},
#               'RestaurantsDelivery': False,
#               'RestaurantsGoodForGroups': True,
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': False,
#                'dinner': False,
#                'brunch': False,
#                'breakfast': False},
#               'GoodForKids': False,
#               'categories': ['Restaurants',
#                'Breakfast & Brunch',
#                'Bars',
#                'Modern European',
#                'Nightlife',
#                'Wine Bars']},
#              'Qnz3ywR7BosTr8qDk6G-Pw': {'RestaurantsPriceRange2': 2,
#               'BikeParking': False,
#               'BusinessAcceptsCreditCards': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'categories': ['Home & Garden',
#                'Mattresses',
#                'Home Decor',
#                'Furniture Stores',
#                'Shopping']},
#              'viivlh_KJkiDVxhIdZnV8Q': {'BusinessAcceptsBitcoin': False,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': True,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': False},
#               'AgesAllowed': 'allages',
#               'Alcohol': 'full_bar',
#               'Smoking': 'outdoor',
#               'GoodForKids': False,
#               'HappyHour': False,
#               'RestaurantsPriceRange2': 2,
#               'HasTV': False,
#               'BusinessAcceptsCreditCards': True,
#               'NoiseLevel': 'very_loud',
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BestNights': {'monday': False,
#                'tuesday': False,
#                'friday': True,
#                'wednesday': False,
#                'thursday': False,
#                'sunday': False,
#                'saturday': False},
#               'WheelchairAccessible': True,
#               'RestaurantsGoodForGroups': True,
#               'BikeParking': True,
#               'CoatCheck': False,
#               'Music': {'dj': False,
#                'background_music': False,
#                'no_music': False,
#                'jukebox': False,
#                'live': True,
#                'video': False,
#                'karaoke': False},
#               'OutdoorSeating': False,
#               'GoodForDancing': True,
#               'categories': ['Arts & Entertainment',
#                'Dance Clubs',
#                'Nightlife',
#                'Music Venues']},
#              'q2KtxnPa6rPSpAlMbg9l8g': {'BikeParking': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsPriceRange2': 2,
#               'RestaurantsTakeOut': True,
#               'RestaurantsDelivery': False,
#               'Caters': True,
#               'categories': ['Desserts', 'Food', 'Cupcakes', 'Bakeries']},
#              'c-BELKj0SvNhBesQMf-bKw': {'BusinessAcceptsCreditCards': True,
#               'categories': ['Convenience Stores',
#                'Automotive',
#                'Food',
#                'Gas Stations',
#                'Grocery']},
#              'qWWBVE5T_zMEF7UJ4iTfNw': {'ByAppointmentOnly': True,
#               'BusinessAcceptsCreditCards': True,
#               'categories': ['Home Services',
#                'Heating & Air Conditioning/HVAC']},
#              'YNvZdMLXa4q8e9tiE4ge4A': {'ByAppointmentOnly': True,
#               'BusinessAcceptsCreditCards': True,
#               'categories': ['Health & Medical', 'Medical Centers']},
#              'cQ8FKduGfVskvi11NZXsAg': {'GoodForKids': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'BikeParking': True,
#               'categories': ['Parks', 'Active Life']},
#              '_J_x_RaYTqAqAuCwgRhnRQ': {'OutdoorSeating': True,
#               'RestaurantsAttire': 'casual',
#               'WiFi': 'free',
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': True,
#                'lot': True,
#                'valet': False},
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': False},
#               'RestaurantsTakeOut': True,
#               'GoodForKids': False,
#               'BikeParking': False,
#               'Caters': True,
#               'RestaurantsPriceRange2': 2,
#               'RestaurantsReservations': True,
#               'RestaurantsDelivery': False,
#               'Alcohol': 'full_bar',
#               'RestaurantsGoodForGroups': True,
#               'HasTV': True,
#               'BusinessAcceptsBitcoin': True,
#               'BusinessAcceptsCreditCards': True,
#               'categories': ['Coffee & Tea',
#                'Hookah Bars',
#                'Nightlife',
#                'Persian/Iranian',
#                'Country Dance Halls',
#                'Middle Eastern',
#                'Beer',
#                'Wine & Spirits',
#                'Bars',
#                'Restaurants',
#                'Food',
#                'Lounges',
#                'Delis']},
#              '0KlYc--jcw4EOYdPS8CDQg': {'BikeParking': False,
#               'BusinessAcceptsBitcoin': False,
#               'GoodForKids': True,
#               'RestaurantsPriceRange2': 2,
#               'HairSpecializesIn': {'straightperms': False,
#                'coloring': False,
#                'extensions': False,
#                'africanamerican': False,
#                'curly': False,
#                'kids': True,
#                'perms': False,
#                'asian': False},
#               'WheelchairAccessible': True,
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'ByAppointmentOnly': False,
#               'BusinessAcceptsCreditCards': True,
#               'categories': ['Beauty & Spas',
#                'Hair Salons',
#                'Kids Hair Salons']},
#              'KSoAqqpLSUHMzpMDf46DMg': {'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'ByAppointmentOnly': False,
#               'BikeParking': False,
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsPriceRange2': 3,
#               'categories': ['Shopping', 'Jewelry']},
#              '6l00a9Gkxkcp_y-GPjYBiw': {'RestaurantsAttire': 'casual',
#               'RestaurantsDelivery': False,
#               'Ambience': {'touristy': False,
#                'hipster': False,
#                'romantic': False,
#                'intimate': False,
#                'trendy': False,
#                'upscale': False,
#                'classy': False,
#                'casual': True},
#               'BikeParking': True,
#               'RestaurantsGoodForGroups': True,
#               'Caters': True,
#               'RestaurantsPriceRange2': 2,
#               'RestaurantsTableService': False,
#               'RestaurantsTakeOut': True,
#               'HasTV': True,
#               'OutdoorSeating': False,
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': True,
#                'brunch': False,
#                'breakfast': False},
#               'GoodForKids': True,
#               'Alcohol': 'none',
#               'NoiseLevel': 'quiet',
#               'RestaurantsReservations': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'categories': ['Fish & Chips', 'Restaurants']},
#              'xu29IdQ4J9o5bffgoONwSA': {'BikeParking': False,
#               'GoodForKids': False,
#               'categories': ['Active Life', 'Golf']},
#              'jtzU8hk78718cNWM_dMcDg': {'RestaurantsPriceRange2': 2,
#               'BusinessAcceptsCreditCards': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'categories': ["Men's Clothing",
#                'Sporting Goods',
#                'Shopping',
#                'Fashion',
#                "Women's Clothing",
#                'Sports Wear']},
#              'a_TfmuLIHsRDyg7aVJQCBQ': {'categories': ['Financial Services',
#                'Banks & Credit Unions']},
#              'qac28VmbQ7OrTMk-RCl7Yg': {'GoodForKids': False,
#               'RestaurantsPriceRange2': 2,
#               'ByAppointmentOnly': False,
#               'BusinessAcceptsCreditCards': True,
#               'BikeParking': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'categories': ['Beauty & Spas',
#                'Skin Care',
#                'Tanning Beds',
#                'Hair Salons',
#                'Tanning']},
#              'dQj5DLZjeDK3KFysh1SYOQ': {'CoatCheck': False,
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'HappyHour': True,
#               'Smoking': 'no',
#               'WiFi': 'free',
#               'RestaurantsTableService': False,
#               'RestaurantsDelivery': False,
#               'Alcohol': 'full_bar',
#               'RestaurantsPriceRange2': 2,
#               'HasTV': False,
#               'Caters': True,
#               'Music': {'dj': False,
#                'background_music': True,
#                'jukebox': False,
#                'live': False,
#                'video': False,
#                'karaoke': False},
#               'RestaurantsTakeOut': True,
#               'BestNights': {'monday': False,
#                'tuesday': False,
#                'friday': True,
#                'wednesday': True,
#                'thursday': True,
#                'sunday': False,
#                'saturday': False},
#               'WheelchairAccessible': True,
#               'BusinessAcceptsCreditCards': True,
#               'GoodForKids': False,
#               'BusinessAcceptsBitcoin': False,
#               'GoodForDancing': False,
#               'BikeParking': True,
#               'RestaurantsAttire': 'casual',
#               'RestaurantsGoodForGroups': True,
#               'NoiseLevel': 'average',
#               'RestaurantsReservations': False,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': True,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': False,
#                'dinner': True,
#                'brunch': False,
#                'breakfast': False},
#               'OutdoorSeating': False,
#               'categories': ['Nightlife',
#                'Bars',
#                'Polish',
#                'Modern European',
#                'Restaurants',
#                'Vegan']},
#              'R3rss9fkfJxiOK6DueON3w': {'categories': ['Shopping',
#                "Women's Clothing",
#                'Fashion']},
#              'Y0dRlYjRNWckjvTGd55hzg': {'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': False,
#                'dinner': False,
#                'brunch': False,
#                'breakfast': False},
#               'RestaurantsGoodForGroups': True,
#               'GoodForKids': True,
#               'RestaurantsTakeOut': True,
#               'categories': ['Caterers', 'Event Planning & Services']},
#              'kJbteCeQTiEB8Xdn9dA7rw': {'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': True,
#               'categories': ['Tree Services',
#                'Landscape Architects',
#                'Home Services',
#                'Landscaping',
#                'Lawn Services']},
#              '5sFVttifV5ID8Gs0-iiAsA': {'ByAppointmentOnly': True,
#               'HairSpecializesIn': {'straightperms': True,
#                'coloring': True,
#                'extensions': True,
#                'africanamerican': True,
#                'curly': True,
#                'kids': True,
#                'perms': True,
#                'asian': True},
#               'WheelchairAccessible': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BusinessAcceptsCreditCards': True,
#               'BusinessAcceptsBitcoin': False,
#               'BikeParking': False,
#               'categories': ['Hair Loss Centers',
#                'Beauty & Spas',
#                'Hair Stylists',
#                'Hair Salons']},
#              '9UTpmQ4OhX5jNFUIu7dPPQ': {'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'RestaurantsDelivery': False,
#               'Caters': False,
#               'RestaurantsTableService': True,
#               'HasTV': False,
#               'RestaurantsTakeOut': True,
#               'Alcohol': 'none',
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'RestaurantsReservations': False,
#               'NoiseLevel': 'average',
#               'GoodForKids': True,
#               'RestaurantsPriceRange2': 1,
#               'RestaurantsAttire': 'casual',
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': True,
#                'brunch': False,
#                'breakfast': False},
#               'OutdoorSeating': False,
#               'RestaurantsGoodForGroups': True,
#               'WiFi': 'no',
#               'BikeParking': True,
#               'categories': ['Restaurants', 'Korean']},
#              'HYunM2pknhIh8lbiMa7THw': {'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': False,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BikeParking': False,
#               'RestaurantsPriceRange2': 2,
#               'categories': ['Interior Design',
#                'Contractors',
#                'Hardware Stores',
#                'Building Supplies',
#                'Home & Garden',
#                'Paint Stores',
#                'Home Services',
#                'Shopping',
#                'Painters']},
#              'v-scZMU6jhnmV955RSzGJw': {'OutdoorSeating': False,
#               'HasTV': True,
#               'NoiseLevel': 'average',
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsTableService': True,
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsDelivery': False,
#               'WiFi': 'no',
#               'RestaurantsReservations': False,
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': False,
#                'brunch': False,
#                'breakfast': False},
#               'RestaurantsTakeOut': True,
#               'Alcohol': 'none',
#               'RestaurantsGoodForGroups': False,
#               'BikeParking': True,
#               'WheelchairAccessible': True,
#               'Caters': True,
#               'Ambience': {'touristy': False,
#                'hipster': False,
#                'romantic': False,
#                'divey': False,
#                'intimate': False,
#                'trendy': False,
#                'upscale': False,
#                'classy': False,
#                'casual': True},
#               'RestaurantsAttire': 'casual',
#               'RestaurantsPriceRange2': 2,
#               'GoodForKids': True,
#               'categories': ['Japanese', 'Sushi Bars', 'Restaurants']},
#              'gS-IoDQSggdxPn2Sf1yfGQ': {'ByAppointmentOnly': True,
#               'categories': ['General Dentistry',
#                'Health & Medical',
#                'Dentists']},
#              'kANF0dbeoW34s2vwh6Umfw': {'RestaurantsPriceRange2': 1,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'RestaurantsGoodForGroups': True,
#               'RestaurantsTakeOut': True,
#               'NoiseLevel': 'average',
#               'BusinessAcceptsCreditCards': True,
#               'RestaurantsAttire': 'casual',
#               'BikeParking': True,
#               'OutdoorSeating': False,
#               'HasTV': False,
#               'RestaurantsReservations': False,
#               'BusinessParking': {'garage': False,
#                'street': False,
# ...
#               'RestaurantsAttire': 'casual',
#               'RestaurantsPriceRange2': 2,
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsGoodForGroups': True,
#               'RestaurantsReservations': False,
#               'RestaurantsDelivery': False,
#               'RestaurantsTakeOut': True,
#               'HasTV': True,
#               'categories': ['Nightlife',
#                'Restaurants',
#                'Bars',
#                'Burgers',
#                'Delis']},
#              'mrTQDyURrL_THMp-nsVquQ': {'categories': ['Pets', 'Pet Stores']},
#              '5G9aIrRiCD4TZCC5j2D39A': {'BusinessAcceptsCreditCards': True,
#               'GoodForKids': False,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'RestaurantsReservations': False,
#               'BikeParking': False,
#               'HasTV': False,
#               'Caters': False,
#               'RestaurantsTakeOut': True,
#               'RestaurantsGoodForGroups': True,
#               'OutdoorSeating': False,
#               'NoiseLevel': 'average',
#               'WiFi': 'free',
#               'RestaurantsAttire': 'casual',
#               'RestaurantsPriceRange2': 1,
#               'RestaurantsDelivery': False,
#               'Alcohol': 'none',
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': False},
#               'categories': ['Bagels',
#                'Donuts',
#                'Coffee & Tea',
#                'Breakfast & Brunch',
#                'Restaurants',
#                'Food']},
#              'y85X24N89dQgbEfGNuj2WQ': {'BusinessAcceptsCreditCards': True,
#               'RestaurantsPriceRange2': 3,
#               'BikeParking': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'categories': ['Shopping', 'Outlet Stores', 'Shopping Centers']},
#              'yXgSKKxG4LDHXzpESmD-tw': {'ByAppointmentOnly': False,
#               'categories': ['Health & Medical', 'Medical Centers']},
#              'c5hK7QFeHpFBTam3N5i4hQ': {'categories': ['Pet Groomers',
#                'Pets',
#                'Pet Sitting',
#                'Pet Services']},
#              'in8uc02eZJbPnDP2PWl8ig': {'categories': ['Sewing & Alterations',
#                'Local Services']},
#              'lTU80hSQiTRLCelBkhEhkQ': {'BusinessAcceptsCreditCards': True,
#               'categories': ['Landscaping', 'Home Services']},
#              'aUh_NqYX0lvK6erjKfJn_A': {'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': True,
#               'categories': ['Dentists',
#                'General Dentistry',
#                'Endodontists',
#                'Cosmetic Dentists',
#                'Health & Medical']},
#              '1us5qNogRwpeI1NkztKa1Q': {'GoodForKids': True,
#               'categories': ['Active Life', 'Amateur Sports Teams']},
#              '6LBMax_eriJaDs2qWQM3Kg': {'GoodForKids': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'BikeParking': True,
#               'categories': ['Parks', 'Active Life']},
#              'ljtJ8In8nEoLkotLwxguPg': {'GoodForKids': True,
#               'RestaurantsPriceRange2': 2,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': True,
#               'categories': ['Beauty & Spas', 'Hair Salons', 'Barbers']},
#              'Es8M4aIZ_KKPb6oUtcdSqw': {'RestaurantsPriceRange2': 2,
#               'WiFi': 'paid',
#               'categories': ['Bars', 'Nightlife', 'Dive Bars']},
#              '6koDlaDeLdZ8ZAMCcQDpkg': {'RestaurantsPriceRange2': 2,
#               'BusinessAcceptsCreditCards': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BikeParking': True,
#               'categories': ["Men's Clothing",
#                'Department Stores',
#                'Shopping',
#                'Plus Size Fashion',
#                'Fashion',
#                'Shoe Stores',
#                'Accessories']},
#              '0Vf9cMIIdH8uNLOtW-Dtjg': {'ByAppointmentOnly': False,
#               'RestaurantsPriceRange2': 3,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'BusinessAcceptsCreditCards': True,
#               'categories': ['Beauty & Spas',
#                'Skin Care',
#                'Hair Removal',
#                'Hair Salons']},
#              'BxRsg5YTYnxXEhoGcabydg': {'WiFi': 'no',
#               'RestaurantsAttire': 'casual',
#               'GoodForKids': True,
#               'BikeParking': True,
#               'RestaurantsGoodForGroups': True,
#               'Caters': True,
#               'BusinessAcceptsCreditCards': True,
#               'NoiseLevel': 'quiet',
#               'categories': ['Mexican', 'Restaurants', 'Food', 'Food Trucks']},
#              'KykaDerdKSmeiyX4L-82uA': {'BikeParking': True,
#               'BusinessAcceptsCreditCards': True,
#               'WheelchairAccessible': True,
#               'ByAppointmentOnly': True,
#               'categories': ['Active Life',
#                'Trainers',
#                'Physical Therapy',
#                'Pilates',
#                'Health & Medical',
#                'Fitness & Instruction',
#                'Cardio Classes']},
#              'EJgC5p_-AxdHaxm9Dh0P5g': {'categories': ['Auto Repair',
#                'Automotive']},
#              'TreYsBGjXptogQQmQh1-bg': {'RestaurantsGoodForGroups': True,
#               'OutdoorSeating': True,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'RestaurantsPriceRange2': 1,
#               'Alcohol': 'none',
#               'RestaurantsAttire': 'casual',
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'RestaurantsDelivery': False,
#               'RestaurantsReservations': False,
#               'Caters': False,
#               'BikeParking': True,
#               'RestaurantsTakeOut': True,
#               'GoodForKids': True,
#               'BusinessAcceptsCreditCards': True,
#               'HasTV': False,
#               'NoiseLevel': 'average',
#               'WiFi': 'no',
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': False,
#                'brunch': False,
#                'breakfast': True},
#               'categories': ['Breakfast & Brunch',
#                'Greek',
#                'American (Traditional)',
#                'Restaurants',
#                'Mediterranean']},
#              'Ycp3Agr7dt71TZkeKV7jng': {'RestaurantsDelivery': False,
#               'RestaurantsGoodForGroups': True,
#               'RestaurantsAttire': 'casual',
#               'Caters': False,
#               'RestaurantsReservations': False,
#               'BikeParking': True,
#               'ByAppointmentOnly': False,
#               'HasTV': False,
#               'RestaurantsTableService': False,
#               'RestaurantsPriceRange2': 2,
#               'GoodForKids': True,
#               'NoiseLevel': 'average',
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'BusinessParking': {'garage': False,
#                'street': True,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'Alcohol': 'none',
#               'OutdoorSeating': True,
#               'RestaurantsTakeOut': True,
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': False,
#                'brunch': True,
#                'breakfast': True},
#               'WiFi': 'free',
#               'categories': ['Restaurants',
#                'Desserts',
#                'Sandwiches',
#                'Cafes',
#                'French',
#                'Coffee & Tea',
#                'Food',
#                'Breakfast & Brunch']},
#              'us8NtNBTEm4k-GKrYKz4Dw': {'RestaurantsPriceRange2': 1,
#               'BikeParking': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'ByAppointmentOnly': False,
#               'GoodForKids': True,
#               'categories': ['Beauty & Spas', 'Barbers', 'Hair Salons']},
#              'OqERAAmawmB0oIAQP8-Ezg': {'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': True,
#               'categories': ['Acupuncture',
#                'Health & Medical',
#                'Naturopathic/Holistic',
#                'Nutritionists',
#                'Weight Loss Centers',
#                'Doctors']},
#              '7IoodTC2xwmBWvoFCP5urg': {'WheelchairAccessible': False,
#               'ByAppointmentOnly': True,
#               'BusinessAcceptsCreditCards': True,
#               'BusinessAcceptsBitcoin': False,
#               'BikeParking': False,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'categories': ['Waxing',
#                'Permanent Makeup',
#                'Day Spas',
#                'Skin Care',
#                'Beauty & Spas',
#                'Hair Removal']},
#              '8N5KG-iuAJrPVL6awBzBaQ': {'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': False,
#               'GoodForKids': True,
#               'BikeParking': True,
#               'DogsAllowed': False,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'categories': ['Gyms',
#                'Trainers',
#                'Active Life',
#                'Fitness & Instruction']},
#              'n9eudXq_35C0htRLtHZ2XQ': {'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': False,
#                'valet': False},
#               'WheelchairAccessible': False,
#               'GoodForDancing': False,
#               'NoiseLevel': 'average',
#               'HappyHour': False,
#               'OutdoorSeating': False,
#               'Music': {'dj': False},
#               'CoatCheck': False,
#               'RestaurantsGoodForGroups': True,
#               'Smoking': 'no',
#               'HasTV': False,
#               'Alcohol': 'full_bar',
#               'RestaurantsReservations': True,
#               'BikeParking': True,
#               'BestNights': {'monday': False,
#                'tuesday': False,
#                'friday': True,
#                'wednesday': False,
#                'thursday': True,
#                'sunday': False,
#                'saturday': True},
#               'RestaurantsPriceRange2': 1,
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'categories': ['Beer',
#                'Wine & Spirits',
#                'Whiskey Bars',
#                'Coffee & Tea',
#                'Beer Bar',
#                'Breakfast & Brunch',
#                'Bars',
#                'Cocktail Bars',
#                'Food',
#                'Cafes',
#                'Wine Bars',
#                'Restaurants',
#                'Local Flavor',
#                'Nightlife']},
#              '5DVG0kea51olW0_kxNcD9g': {'RestaurantsReservations': True,
#               'RestaurantsPriceRange2': 2,
#               'GoodForKids': True,
#               'Alcohol': 'full_bar',
#               'Caters': False,
#               'OutdoorSeating': True,
#               'BikeParking': True,
#               'RestaurantsTakeOut': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'HasTV': True,
#               'GoodForMeal': {'dessert': False,
#                'latenight': False,
#                'lunch': True,
#                'dinner': True,
#                'brunch': False,
#                'breakfast': False},
#               'RestaurantsDelivery': False,
#               'RestaurantsGoodForGroups': True,
#               'RestaurantsAttire': 'casual',
#               'WiFi': 'no',
#               'Ambience': {'romantic': False,
#                'intimate': False,
#                'classy': False,
#                'hipster': False,
#                'divey': False,
#                'touristy': False,
#                'trendy': False,
#                'upscale': False,
#                'casual': True},
#               'HappyHour': True,
#               'NoiseLevel': 'very_loud',
#               'categories': ['Sports Bars',
#                'Nightlife',
#                'Bars',
#                'Chicken Wings',
#                'Restaurants',
#                'American (Traditional)']},
#              'Pmb9R4aEyMWVYCIStUZBTg': {'BusinessAcceptsCreditCards': False,
#               'categories': ['Motorcycle Dealers',
#                'Automotive',
#                'Motorcycle Repair']},
#              'jg72eKbD8rlv0i1DRN5uxQ': {'BusinessAcceptsCreditCards': True,
#               'BusinessParking': {'garage': False,
#                'street': False,
#                'validated': False,
#                'lot': True,
#                'valet': False},
#               'RestaurantsPriceRange2': 2,
#               'categories': ['Video Game Stores',
#                'Videos & Video Game Rental',
#                'Shopping',
#                'Books',
#                'Mags',
#                'Music & Video',
#                'Hobby Shops']},
#              '22emEUJINj455l5gnWbDQg': {'BusinessAcceptsCreditCards': True,
#               'ByAppointmentOnly': False,
#               'categories': ['Auto Parts & Supplies',
#                'Automotive',
#                'Car Dealers',
#                'Auto Repair']},
#              'J38n-oFC0V_PUo4qcTxang': {'BusinessAcceptsBitcoin': False,
#               'BusinessAcceptsCreditCards': True,
#               'categories': ['Appliances & Repair', 'Local Services']},
#              '-DXRTcIIFSDFaec9SozG3A': {'categories': ['African',
#                'Restaurants']},
#              'Wc0Leurb7WMVrP3KIZYiUw': {'ByAppointmentOnly': True,
#               'categories': ['Dentists', 'Health & Medical', 'Oral Surgeons']},
#              ...})
